# %%
import pandas as pd

# %%
emp=pd.read_excel(r'C:\Users\srisa\Downloads\Rawdata.xlsx')

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
id(emp)
# Out:
# 1539476012304

# %%
emp.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp.isna()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %% [markdown]
# # DATA CLEANING OR DATA CLEANISING

# %%
emp['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp['Name']=emp['Name'].str.replace(r'\W','',regex=True)

# %%
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Domain']=emp['Domain'].str.replace(r'\W','',regex=True)

# %%
emp['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
emp
# Out:
#     Name       Domain       Age   Location   Salary      Exp
# 0   Mike  Datascience  34 years     Mumbai   5^00#0       2+
# 1  Teddy      Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst       NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim          NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Age']=emp['Age'].str.replace(r'\W','',regex=True)

# %%
emp
# Out:
#     Name       Domain      Age   Location   Salary      Exp
# 0   Mike  Datascience  34years     Mumbai   5^00#0       2+
# 1  Teddy      Testing     45yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst      NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics      NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics     67yr        NaN   30000-  5+ year
# 5    Kim          NLP     55yr      Delhi  6000^$0      10+

# %%
emp['Salary']=emp['Salary'].str.replace(r'\W','',regex=True)

# %%
emp
# Out:
#     Name       Domain      Age   Location Salary      Exp
# 0   Mike  Datascience  34years     Mumbai   5000       2+
# 1  Teddy      Testing     45yr  Bangalore  10000       <3
# 2   Umar  Dataanalyst      NaN        NaN  15000   4> yrs
# 3   Jane    Analytics      NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics     67yr        NaN  30000  5+ year
# 5    Kim          NLP     55yr      Delhi  60000      10+

# %%
emp['Age']=emp['Age'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\srisa\AppData\Local\Temp\ipykernel_13036\3771958390.py:1: SyntaxWarning: invalid escape sequence '\d'
#   emp['Age']=emp['Age'].str.extract('(\d+)')

# %%
emp['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
emp['Location']=emp['Location'].str.replace(r'\W','',regex=True)

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
emp['Exp']=emp['Exp'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\srisa\AppData\Local\Temp\ipykernel_13036\1466635560.py:1: SyntaxWarning: invalid escape sequence '\d'
#   emp['Exp']=emp['Exp'].str.extract('(\d+)')

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data=emp

# %% [markdown]
# # EDA TECHNIQUE

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
import numpy as np

# %%
clean_data['Age']=clean_data['Age'].fillna(np.mean(pd.to_numeric(clean_data['Age'])))

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  NaN
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
clean_data['Exp']=clean_data['Exp'].fillna(np.mean(pd.to_numeric(clean_data['Exp'])))

# %%
clean_data['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    4.8
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
clean_data['Location']=clean_data['Location'].fillna(clean_data['Location'].mode()[0])

# %%
clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2    Bangalore
# 3     Hyderbad
# 4    Bangalore
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25  Bangalore  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67  Bangalore  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
clean_data['Age']=clean_data['Age'].astype(int)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      int32
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: int32(1), object(5)
# memory usage: 396.0+ bytes

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst   50  Bangalore  15000    4
# 3   Jane    Analytics   50   Hyderbad  20000  4.8
# 4  Uttam   Statistics   67  Bangalore  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data['Salary']=clean_data['Salary'].astype(int)

# %%
clean_data['Exp']=clean_data['Exp'].astype(int)

# %%
clean_data.dtypes
# Out:
# Name        object
# Domain      object
# Age          int32
# Location    object
# Salary       int32
# Exp          int32
# dtype: object

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data['Name'] = clean_data['Name'].astype('category')
clean_data['Domain'] = clean_data['Domain'].astype('category')
clean_data['Location'] = clean_data['Location'].astype('category')

# %%
clean_data.dtypes
# Out:
# Name        category
# Domain      category
# Age            int32
# Location    category
# Salary         int32
# Exp            int32
# dtype: object

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data.to_csv('clean_data.csv')

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\srisa'

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %% [markdown]
# # EDA TECHNIQUE LETS APPLY

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clean_data['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: int32

# %%
v = sns.distplot(clean_data['Salary'])

# %%
v1=sns.histplot(clean_data['Salary'])

# %%
v2=plt.hist(clean_data['Salary'])

# %%
v3=sns.lmplot(data=clean_data,x='Exp',y='Salary')

# %%
v3=sns.lmplot(data=clean_data,x='Exp',y='Salary',fit_reg=False)

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
plt.bar(x=[0, 1, 2, 3, 4, 5], height=clean_data['Age'])
plt.show()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data[:]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
clean_data[::-1]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 5    Kim          NLP   55      Delhi   60000   10
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 1  Teddy      Testing   45  Bangalore   10000    3
# 0   Mike  Datascience   34     Mumbai    5000    2

# %%
clean_data.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
x_iv = clean_data[['Name', 'Domain', 'Age', 'Location', 'Exp']]

# %%
x_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience   34     Mumbai    2
# 1  Teddy      Testing   45  Bangalore    3
# 2   Umar  Dataanalyst   50  Bangalore    4
# 3   Jane    Analytics   50   Hyderbad    4
# 4  Uttam   Statistics   67  Bangalore    5
# 5    Kim          NLP   55      Delhi   10

# %%
y_dv = clean_data[['Salary']]

# %%
y_dv
# Out:
#    Salary
# 0    5000
# 1   10000
# 2   15000
# 3   20000
# 4   30000
# 5   60000

# %%
clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67  Bangalore   30000    5
# 5    Kim          NLP   55      Delhi   60000   10

# %%
Imputation=pd.get_dummies(clean_data)

# %%
Imputation
# Out:
#    Age  Salary  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0   34    5000    2      False     False       True       False      False
# 1   45   10000    3      False     False      False        True      False
# 2   50   15000    4      False     False      False       False       True
# 3   50   20000    4       True     False      False       False      False
# 4   67   30000    5      False     False      False       False      False
# 5   55   60000   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  Domain_Datascience  \
# 0       False             False               False                True
# 1       False             False               False               False
# 2       False             False                True               False
# 3       False              True               False               False
# 4        True             False               False               False
# ...

# %% [markdown]
# ### raw data with lot of regex, missing, uncleandata
# ### regex, clean
# ## fill missing numerical & cateigroica
# ## clean_dataset ( data cleaning) 3 month - 5mont
# ## outlier treatement, univati, bivariate, corelation
# ## split the data into x_i.v & y_dv
# ## impute cateogrica data to numerical
# ## eda part complete
